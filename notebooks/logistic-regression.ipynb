# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
from PIL import Image
from scipy import ndimage
from sklearn.datasets import load_breast_cancer as load_dataset
from sklearn import preprocessing

# %%
split = .8;
data = load_dataset()
split = int(len(data.data) * .8)
train_set_x_orig = data.data[:int(len(data.data) * .8)]
train_set_y_orig = data.target[:int(len(data.data) * .8)]
test_set_x_orig = data.data[int(len(data.data) * .8):]
test_set_y_orig = data.target[int(len(data.data) * .8):]

# %%
m_train = train_set_x_orig.shape[0]
m_test = test_set_x_orig.shape[0]
num_px = train_set_x_orig.shape[1]

# %%
#scale data to [0,1]
min_max_scaler = preprocessing.MinMaxScaler()
X_train = min_max_scaler.fit_transform(train_set_x_orig)
X_train = X_train.reshape(num_px, m_train)
X_test = min_max_scaler.fit_transform(test_set_x_orig)
X_test = X_test.reshape(num_px, m_test)
y_train = np.expand_dims(train_set_y_orig, axis=0)
y_test = np.expand_dims(test_set_y_orig, axis=0)

# %%
# Sigmoid of Z
def sigmoid(z):
    return 1 / (1 + np.exp(-z))


def initialize(dim):
    w = np.expand_dims(np.random.rand(dim), axis = 1)
    b = 0
    return w, b

def propagate(w, b, X, Y):

    m = X.shape[1]
    A = sigmoid(np.dot(w.T, X) + b)    
    cost = (-1/m) * (np.sum((Y * np.log(A)) + ((1 - Y) * np.log(1 - A))))   
    
    dw = (1/m) * np.dot(X, (np.subtract(A,Y)).T)
    db = (1/m) * np.sum(A - Y)

    
    cost = np.squeeze(cost)

    grads = {"dw": dw,
             "db": db}
    
    return grads, cost

def optimize(w, b, X, Y, num_iterations, learning_rate, print_cost = False):
    
    costs = []
    
    for i in range(num_iterations):
        
        grads, cost = propagate(w, b, X, Y)

        dw = grads["dw"]
        db = grads["db"]
        
        w = w - (learning_rate * dw)
        b = b - (learning_rate * db)
        
        if i % 100 == 0:
            costs.append(cost)
        
        if print_cost and i % 100 == 0:
            print ("Cost after iteration %i: %f" %(i, cost))
    
    params = {"w": w,
              "b": b}
    
    grads = {"dw": dw,
             "db": db}
    
    return params, grads, costs

def predict(w, b, X):
    
    m = X.shape[1]
    Y_prediction = np.zeros((1,m))
    w = w.reshape(X.shape[0], 1)
    
    A = sigmoid(np.dot(w.T, X) + b)
    
    A[A > 0.5] = 1
    A[A <= 0.5] = 0
    Y_prediction = A

    return Y_prediction

def model(X_train, Y_train, X_test, Y_test, num_iterations = 2000, learning_rate = 0.5, print_cost = False):

    w, b = initialize(X_train.shape[0])

    parameters, grads, costs = optimize(w, b, X_train, Y_train, num_iterations, learning_rate, print_cost)
    
    w = parameters["w"]
    b = parameters["b"]
    
    Y_prediction_test = predict(w, b, X_test)
    Y_prediction_train = predict(w, b, X_train)

    print("train accuracy: {} %".format(100 - np.mean(np.abs(Y_prediction_train - Y_train)) * 100))
    print("test accuracy: {} %".format(100 - np.mean(np.abs(Y_prediction_test - Y_test)) * 100))

    d = {"costs": costs,
         "Y_prediction_test": Y_prediction_test, 
         "Y_prediction_train" : Y_prediction_train, 
         "w" : w, 
         "b" : b,
         "learning_rate" : learning_rate,
         "num_iterations": num_iterations}
    
    return d

d = model(X_train, y_train, X_test, y_test, num_iterations = 10000, learning_rate = 0.001, print_cost = True)
# Out:
# Cost after iteration 0: 1.552904
# Cost after iteration 100: 1.510827
# Cost after iteration 200: 1.469437
# Cost after iteration 300: 1.428791
# Cost after iteration 400: 1.388949
# Cost after iteration 500: 1.349972
# Cost after iteration 600: 1.311922
# Cost after iteration 700: 1.274862
# Cost after iteration 800: 1.238855
# Cost after iteration 900: 1.203961
# Cost after iteration 1000: 1.170238
# Cost after iteration 1100: 1.137742
# Cost after iteration 1200: 1.106522
# Cost after iteration 1300: 1.076623
# Cost after iteration 1400: 1.048082
# Cost after iteration 1500: 1.020929
# Cost after iteration 1600: 0.995186
# Cost after iteration 1700: 0.970865
# Cost after iteration 1800: 0.947969
# Cost after iteration 1900: 0.926491
# Cost after iteration 2000: 0.906414
# Cost after iteration 2100: 0.887714
# Cost after iteration 2200: 0.870357
# Cost after iteration 2300: 0.854301
# Cost after iteration 2400: 0.839498
# Cost after iteration 2500: 0.825894
# Cost after iteration 2600: 0.813430
# Cost after iteration 2700: 0.802044
# Cost after iteration 2800: 0.791673
# Cost after iteration 2900: 0.782250
# Cost after iteration 3000: 0.773710
# Cost after iteration 3100: 0.765989
# Cost after iteration 3200: 0.759022
# Cost after iteration 3300: 0.752749
# Cost after iteration 3400: 0.747110
# Cost after iteration 3500: 0.742048
# Cost after iteration 3600: 0.737513
# Cost after iteration 3700: 0.733453
# Cost after iteration 3800: 0.729822
# Cost after iteration 3900: 0.726579
# Cost after iteration 4000: 0.723684
# Cost after iteration 4100: 0.721100
# Cost after iteration 4200: 0.718795
# Cost after iteration 4300: 0.716739
# Cost after iteration 4400: 0.714906
# Cost after iteration 4500: 0.713269
# Cost after iteration 4600: 0.711809
# Cost after iteration 4700: 0.710504
# Cost after iteration 4800: 0.709337
# Cost after iteration 4900: 0.708293
# Cost after iteration 5000: 0.707357
# Cost after iteration 5100: 0.706516
# Cost after iteration 5200: 0.705760
# Cost after iteration 5300: 0.705079
# Cost after iteration 5400: 0.704463
# Cost after iteration 5500: 0.703905
# Cost after iteration 5600: 0.703397
# Cost after iteration 5700: 0.702935
# Cost after iteration 5800: 0.702512
# Cost after iteration 5900: 0.702124
# Cost after iteration 6000: 0.701767
# Cost after iteration 6100: 0.701436
# Cost after iteration 6200: 0.701129
# Cost after iteration 6300: 0.700843
# Cost after iteration 6400: 0.700575
# Cost after iteration 6500: 0.700323
# Cost after iteration 6600: 0.700085
# Cost after iteration 6700: 0.699859
# Cost after iteration 6800: 0.699644
# Cost after iteration 6900: 0.699439
# Cost after iteration 7000: 0.699242
# Cost after iteration 7100: 0.699053
# Cost after iteration 7200: 0.698870
# Cost after iteration 7300: 0.698693
# Cost after iteration 7400: 0.698521
# Cost after iteration 7500: 0.698353
# Cost after iteration 7600: 0.698189
# Cost after iteration 7700: 0.698029
# Cost after iteration 7800: 0.697872
# Cost after iteration 7900: 0.697718
# Cost after iteration 8000: 0.697566
# Cost after iteration 8100: 0.697416
# Cost after iteration 8200: 0.697268
# Cost after iteration 8300: 0.697122
# Cost after iteration 8400: 0.696977
# Cost after iteration 8500: 0.696834
# Cost after iteration 8600: 0.696692
# Cost after iteration 8700: 0.696551
# Cost after iteration 8800: 0.696411
# Cost after iteration 8900: 0.696272
# Cost after iteration 9000: 0.696134
# Cost after iteration 9100: 0.695997
# Cost after iteration 9200: 0.695860
# Cost after iteration 9300: 0.695724
# Cost after iteration 9400: 0.695588
# Cost after iteration 9500: 0.695454
# Cost after iteration 9600: 0.695319
# Cost after iteration 9700: 0.695185
# Cost after iteration 9800: 0.695052
# Cost after iteration 9900: 0.694919
# train accuracy: 57.142857142857146 %
# test accuracy: 76.31578947368422 %
